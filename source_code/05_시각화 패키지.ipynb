# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 한글 문제
# matplotlib의 기본 폰트에서 한글이 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
import pandas as pd
import numpy as np

# %%
plt.plot([1,4,9,16])
plt.show()

# %%
x=[0,1,2,3,4,5,6]
y=[1,4,5,8,9,5,3]

plt.figure(figsize=(8,6))

plt.plot(x,y,color='blue', linestyle='dashdot')
plt.show()

# %%
x=[0,1,2,3,4,5,6]
y=[1,4,5,8,9,5,3]

plt.figure(figsize=(8,6))

plt.plot(x,y,color='red', linestyle='dashdot', marker='o')
plt.show()

# %%
plt.plot([10,20,30,40],[1,4,9,16],
        c='b',
        lw='5',
        ls='--',
        marker='o',
        ms=15,
        mec='g',
        mew=5,
        mfc='r')
plt.title("마커 스타일 적용 예")
plt.show()

# %%
x=[10,20,30,40,50,60]
y=[11,15,40,30,20,10]

plt.plot(x,y,color='green',
        linestyle='dashed',marker='o')  # bar의 경우 plt.bar

plt.xticks(x,("10대","20대","30대","40대","50대","60대"))
plt.yticks(y, (y[i] for i in range(6)))


plt.xlabel("나이")
plt.ylabel("수")

plt.show()

# %%
# x, y 값 지정
plt.figure(figsize=(8,5))
sns.boxplot(x='day', y='total_bil', data=tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-637a064b3842> in <module>
#       1 # x, y 값 지정
#       2 plt.figure(figsize=(8,5))
# ----> 3 sns.boxplot(x='day', y='total_bil', data=tips)
#       4 plt.show()
#
# NameError: name 'sns' is not defined

# %%
# 범주형 변수 처리
#카테고리값을 갖는 변수변수의 이름을 hue 인수에 지정
#카테고리 값에 따라 다르게 시각화됨

#범주형 변수

plt.figure(figsize=(8,5))
sns.boxplot(x='day', y='total_bil', hue='smoker', data=tips, palette='RdYlGn')
plt.show()

# %%
import seaborn
import folium

# %%
# 서울 시청 마커 표시, popup 출력 : '서울 시청'
# 덕수궁에 서클 마커 표시, popup 출력
# 덕수궁 : 37.5658049, 126.9751461000007
seoul_city_map = folium.Map(location=[37.566345, 126.977893], zoom_start=17)

folium.Marker([37.566345, 126.977893], popup='시청').add_to(seoul_city_map)

folium.CircleMarker([37.5658049, 126.9751461000007],
                   popup='덕수궁',
                   radius = 50,
                   color = 'red',
                   fill_color = 'blue').add_to(seoul_city_map)

seoul_city_map.save('../data/seoul_city_map.html')
seoul_city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map.choropleth(){
    geo_data ="",
    data="",
    columns="",
    key_on="",
    fill_color=""
}

# %%
korea_pop = pd.read_excel('../data/korea_population.xls', index_col='ID')
korea_pop.head()
# Out:
#        광역시도   시도  20-39세여자  20-39세합계  65세이상합계     인구수남자   인구수여자     인구수합계  \
# ID
# 강릉      강원도  강릉시   23098.0   49384.0  37679.0  106231.0  107615  213846.0
# 고성(강원)  강원도  고성군    2529.0    7023.0   7151.0   15899.0   14215   30114.0
# 동해      강원도  동해시    9753.0   21264.0  15124.0   47166.0   46131   93297.0
# 삼척      강원도  삼척시    7115.0   15823.0  14610.0   35253.0   34346   69599.0
# 속초      강원도  속초시    8752.0   18708.0  12752.0   40288.0   41505   81793.0
#
#             소멸비율  소멸위기지역  y   x       여성비    2030여성비
# ID
# 강릉      1.226041       0  3  11  0.323597  -3.227766
# 고성(강원)  0.707314       1  0  10 -2.796042 -13.989748
# 동해      1.289738       0  4  11 -0.554680  -4.133747
# 삼척      0.973990       1  5  11 -0.651590  -5.033812
# 속초      1.372647       0  1  10  0.743951  -3.217875

# %%
import folium
import json
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
geo_path='../data/skorea_municipalities_geo_simple.json'
geo_str=json.load(open(geo_path,encoding='utf-8'))

# %%
map = folium.Map(location=[36.2002,127.054], zoom_start=7)

map.choropleth(geo_data=geo_str,
              data=korea_pop['인구수합계'],
              columns=[korea_pop.index, korea_pop['인구수합계']],
              fill_color='YlGnBu',
              key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map = folium.Map(location=[36.2002,127.054], zoom_start=7)

map.choropleth(geo_data=geo_str,
              data=korea_pop['소멸위기지역'],
              columns=[korea_pop.index, korea_pop['소멸위기지역']],
              fill_color='PuRd',
              key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
crime=pd.read_csv('../data/crime_in_Seoul.csv', index_col=0, encoding='utf-8')
crime.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  1.000000  1.000000  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.467528  0.437969  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.133118  0.415445  82.352941   92.857143
# 강서구  0.461095  0.470588  0.416667  0.370649  0.614945  72.900763  100.000000
# 관악구  0.628242  0.411765  0.583333  0.589523  0.647479  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄         검거
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  3238  0.007773  85.463066
# 강동구   75.000000  33.347422  82.890855  453233.0  1010  0.002059  85.550226
# 강북구  100.000000  43.096234  88.637222  330192.0   831  0.002627  94.070728
# 강서구  100.000000  60.114504  84.752105  603772.0   911  0.003734  96.572809
# 관악구   88.888889  30.561715  80.109157  525515.0  2109  0.004577  85.212224

# %%
geo_path='../data/seoul_geo_simple.json'
geo_str=json.load(open(geo_path,encoding='utf-8'))

# %%
#서울시 중심 위도와 경도로 지정
map = folium.Map(location=[37.5502,126.982], zoom_start=11)

#컬러맵은 '살인' 발생 건수로 지정
map.choropleth(geo_data=geo_str,
              data=crime['살인'],
              columns=[crime.index, crime['살인']],
              fill_color='PuRd',
              key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#서울시 중심 위도와 경도로 지정
map = folium.Map(location=[37.5502,126.982], zoom_start=11)

#컬러맵은 'CCTV' 발생 건수로 지정
map.choropleth(geo_data=geo_str,
              data=crime['CCTV'],
              columns=[crime.index, crime['CCTV']],
              fill_color='PuRd',
              key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
