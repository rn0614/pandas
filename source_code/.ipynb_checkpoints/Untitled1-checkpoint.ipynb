# %%
import pandas as pd
import numpy as np

# %%
sample= pd.read_csv('../data/sample.csv', encoding ='utf-8')

# %%
sample.head()
# Out:
#        허가구역명  장소유형   시도명     시군구명                     소재지도로명주소  \
# 0     완산쳬련공원     3    13  전주시 완산구  전라북도 전주시 완산구 모악산자락길 22(중인동)
# 1   부곡온천관광특구     2  경상남도      창녕군                          NaN
# 2  우포 잠자리 나라     2  경상남도      창녕군                          NaN
# 3  고속국도 졸음쉼터     1   경기도      양주시    경기도 양주시 장흥면 서울외곽순환고속도로 58
# 4    영상강문화공원     4  전라남도      담양군                          NaN
#
#                   소재지지번주소         위도          경도  푸드트럭운영대수      허가구역사용료  ...  \
# 0  전라북도 전주시 완산구 중인동 361-1  35.767445  127.101549       1.0    월 55,000원  ...
# 1  경상남도 창녕군 부곡면 거문리 723-2  35.441552  128.535214       1.0            0  ...
# 2  경상남도 창녕군 이방면 안리 1360-1  35.566697  128.416936       1.0            0  ...
# 3  경기도 양주시 장흥면 삼하리 250-16  37.679198  126.915782       1.0  월6,500,000원  ...
# 4  전라남도 담양군 담양읍 향교리 271-8  35.325205  126.987889       2.0    월 338080원  ...
#
#   11월운영시작시각 11월운영종료시각 12월운영시작시각 12월운영종료시각  판매제한품목                 관리기관명  \
# ...

# %%
sample2=sample[['허가구역명','위도','경도','푸드트럭운영대수']]
sample2.head()
# Out:
#        허가구역명         위도          경도  푸드트럭운영대수
# 0     완산쳬련공원  35.767445  127.101549       1.0
# 1   부곡온천관광특구  35.441552  128.535214       1.0
# 2  우포 잠자리 나라  35.566697  128.416936       1.0
# 3  고속국도 졸음쉼터  37.679198  126.915782       1.0
# 4    영상강문화공원  35.325205  126.987889       2.0
