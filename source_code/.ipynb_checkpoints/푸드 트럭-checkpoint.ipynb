# %%
import pandas as pd
import numpy as np

# %%
food_truck = pd.read_csv('../data/food_truck.csv', encoding='utf-8')
food_truck.head(10)
# Out:
#               허가구역명  장소유형    시도명     시군구명                     소재지도로명주소  \
# 0            완산쳬련공원     3     13  전주시 완산구  전라북도 전주시 완산구 모악산자락길 22(중인동)
# 1          부곡온천관광특구     2   경상남도      창녕군                          NaN
# 2         우포 잠자리 나라     2   경상남도      창녕군                          NaN
# 3         고속국도 졸음쉼터     1    경기도      양주시    경기도 양주시 장흥면 서울외곽순환고속도로 58
# 4           영상강문화공원     4   전라남도      담양군                          NaN
# 5  인제군농특산물전시판매장 주차장    99    강원도      인제군           강원도 인제군 인제읍 비봉로 48
# 6           어울림근린공원     4    경기도     동두천시                          NaN
# 7     캠프보산 월드푸드스트리트     8    경기도     동두천시                          NaN
# 8           원주종합체육관     3    강원도      원주시             강원도 원주시 서원대로 281
# 9             강변축구장     3  대구광역시       북구   대구광역시 북구 조야로2길 113-30(서변동)
#
#                   소재지지번주소         위도          경도  푸드트럭운영대수  \
# 0  전라북도 전주시 완산구 중인동 361-1  35.767445  127.101549       1.0
# 1  경상남도 창녕군 부곡면 거문리 723-2  35.441552  128.535214       1.0
# 2  경상남도 창녕군 이방면 안리 1360-1  35.566697  128.416936       1.0
# 3  경기도 양주시 장흥면 삼하리 250-16  37.679198  126.915782       1.0
# 4  전라남도 담양군 담양읍 향교리 271-8  35.325205  126.987889       2.0
# 5     강원도 인제군 인제읍 상동리 430  38.065268  128.174470       2.0
# 6      경기도 동두천시 생연동 714-6  37.896611  127.051710       1.0
# 7     경기도 동두천시 보산동 429-19  37.916468  127.056263      12.0
# 8                     NaN  37.339061  127.941916       5.0
# 9                     NaN  35.908987  128.590347       NaN
#
#                       허가구역사용료  ... 11월운영시작시각 11월운영종료시각 12월운영시작시각 12월운영종료시각  \
# 0                   월 55,000원  ...       NaN       NaN       NaN       NaN
# 1                           0  ...     09:00     22:00     09:00     20:00
# 2                           0  ...     09:00     22:00     09:00     20:00
# 3                 월6,500,000원  ...       NaN       NaN       NaN       NaN
# 4                   월 338080원  ...     10:00     19:00     10:00     19:00
# 5  공시지가(원) × 면적 × 1(년) × 0.05  ...       NaN       NaN       NaN       NaN
# 6                  년 257,100원  ...     10:00     21:00     10:00     21:00
# 7                년 1,000,000원  ...     18:00     23:00     00:00     00:00
# 8                    일 4,860원  ...       NaN       NaN       NaN       NaN
# 9                   월 89,480원  ...       NaN       NaN       NaN       NaN
#
#    판매제한품목                 관리기관명       관리기관전화번호     데이터기준일자   제공기관코드     제공기관명
# 0     NaN  전라북도 전주시시설관리공단 공원운영부   063-239-2568  2019-08-30  4640000  전라북도 전주시
# 1  허가품목 외                  창녕군청   055-530-1094  2020-07-17  5410000  경상남도 창녕군
# 2  허가품목 외                  창녕군청   055-530-1094  2020-07-17  5410000  경상남도 창녕군
# 3     NaN             양주시 민원봉사과  031-8082-5292  2020-05-26  5590000   경기도 양주시
# 4     NaN                   담양군   061-380-2807  2020-10-16  4850000  전라남도 담양군
# 5      주류                   인제군   033-460-2246  2020-10-15  4330000   강원도 인제군
# 6      주류         동두천시청 농업축산위생과   031-860-2232  2020-06-30  3920000  경기도 동두천시
# 7      주류           동두천시총 전략사업과   031-860-2275  2020-06-30  3920000  경기도 동두천시
# 8     NaN           원주시 체육시설사업소   033-737-4302  2020-05-12  4190000   강원도 원주시
# 9     NaN          대구광역시 북구 위생과   053-665-2754  2020-10-13  3450000  대구광역시 북구
#
# [10 rows x 47 columns]

# %%
food_truck.columns
# Out:
# Index(['허가구역명', '장소유형', '시도명', '시군구명', '소재지도로명주소', '소재지지번주소', '위도', '경도',
#        '푸드트럭운영대수', '허가구역사용료', '허가구역운영시작일자', '허가구역운영종료일자', '허가구역휴무일',
#        '허가구역평일운영시작시각', '허가구역평일운영종료시각', '허가구역주말운영시작시각', '허가구역주말운영종료시각',
#        '1월운영시작시각', '1월운영종료시각', '2월운영시작시각', '2월운영종료시각', '3월운영시작시각', '3월운영종료시각',
#        '4월운영시작시각', '4월운영종료시각', '5월운영시작시각', '5월운영종료시각', '6월운영시작시각', '6월운영종료시각',
#        '7월운영시작시각', '7월운영종료시각', '8월운영시작시각', '8월운영종료시각', '9월운영시작시각', '9월운영종료시각',
#        '10월운영시작시각', '10월운영종료시각', '11월운영시작시각', '11월운영종료시각', '12월운영시작시각',
#        '12월운영종료시각', '판매제한품목', '관리기관명', '관리기관전화번호', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')

# %%
food_truck.rename(columns={food_truck.columns[0] :'구별'},inplace=True)

# %%
food_truck2=food_truck[['구별','위도','경도','푸드트럭운영대수']]
food_truck2.head()
# Out:
#           구별         위도          경도  푸드트럭운영대수
# 0     완산쳬련공원  35.767445  127.101549       1.0
# 1   부곡온천관광특구  35.441552  128.535214       1.0
# 2  우포 잠자리 나라  35.566697  128.416936       1.0
# 3  고속국도 졸음쉼터  37.679198  126.915782       1.0
# 4    영상강문화공원  35.325205  126.987889       2.0

# %%
food_truck2['구별'].unique()
food_truck4.drop_duplicates(['구별'])
# Out:
# array(['완산쳬련공원', '부곡온천관광특구', '우포 잠자리 나라', '고속국도 졸음쉼터', '영상강문화공원',
#        '인제군농특산물전시판매장 주차장', '어울림근린공원', '캠프보산 월드푸드스트리트', '원주종합체육관', '강변축구장',
#        '검단졸음쉼터(부산방향)', '검단졸음쉼터(서울방향)', '구수산도서관 주차장', '안성시종합운동장', '한경대',
#        '안성맞춤랜드', '강화군 화도면', '교동면 난정저수지', '수성랜드', '진포해양테마공원 내', '옥도면 장자도리',
#        '서룡공원(서룡A)', '푸드트럭존', '성모병원사거리', '양재역 1번', '양재역 5번', '신사역', '금강제화',
#        '반포쇼핑타운4동', '남부터미널', '금산군푸드트럭존', '우포늪생태공원', '남지읍수변생태공원',
#        '낙동강하천공원주차장', '남조로 사려니숲길입구', '구)탐라대교차로', '부산대학교내 장승터', '금양초등학교',
#        '부산가톨릭대학교 로사리오광장', '홍예공원', '체육공원', '빨간카페', '가야진사공원(원동A)',
#        '서룡공원(서룡B)', '황산공원(황산A)', '황산공원(황산B)', '황산공원(황산C)', '황산공원(황산D))',
#        '가산공원', '부천종합운동장', '소사국민체육센터', '남해유배문학관', '창선교 밑',
#        '경상남도수산기술사업소 남해사무소', '팜랜드', '구석기', '쉬림프 파파', '뉴욕커 핫도그',
#        '로하스 캠핑테리아', '부산시청 푸드트럭존', '아시아드주경기장', '사랑을 볶는 카페', '뉴욕타이거푸드카페',
#        '우리가족', '사천대교왕씨앗호떡', '누누토스트', '구좌 해안도로', '수목원테마파크', '새별오름',
#        '고속도로 졸음쉼터', '광명동굴 내', '송림테마거리', '선린대학교', '칠포해수욕장', '영일대해수욕장',
#        '포항대학교 학교주차장', '팔달문 차없는 거리 및 지동교', '입곡군립공원 주차장', '입곡군립공원 아라힐링카페',
#        '악양생태공원', '강나루생태공원', '중부선 농다리 졸음쉼터', '서울외곽고속도로 김포TG외측 졸음쉼터',
#        '한강신도시 호수공원', '해운대구청', '안중시장 고객센터 앞', '산청 동의보감촌 입구주차장',
#        '광양국민체육센터 커피하우스', '서구문화회관', '앵강소공원내', '송정해수욕장 주차장', '서울혁신파크',
#        '경인아라뱃길 시천교', '양서친환경도서관 앞', '우치공원', '청양공설운동장', '칠갑산오토캠핑장',
#        '청양군민체육관', '치즈체험장', '동해시웰빙스포츠타운 일원', '포항운전면허시험장', '포항종합공설운동장일대',
#        '형산강변 연일대교 하단 일원', '백양공원', '사적지 제229호 충의사 주차장',
#        '유형문화재 제43호 추사고택 주차장', '예당관광지 주차장', '의좋은형제공원 주차장',
#        '덕산도립공원 수덕사 주차장', '무한천체육공원 주차장', '국립공주대학교 산업과학대학 주차장',
#        '봉수산자연휴양림(수목원) 주차장', '예산황새공원 주차장', '강진오감통', '고려청자박물관', '시문학파기념관',
#        '다산박물관', '강진군도서관', '강진군아트홀', '병지방계곡', '산격대교 인근 축제장', '북구청광장',
#        '노작호수공원', '남양근린공원', '동학산근린공원', '다람산근린공원', '장안휴게소', '수원대학교',
#        '푸드트럭허가구역', '곤지암도자기공원', '곤지암팀업캠퍼스', '광주시청', '청석공원', '상림고운광장',
#        '함평공영주차장 내(현재 미운영)', '자연학습공원', '왕송호수공원', '의왕시청', '청계TG졸음쉼터',
#        '청계산 공영주차장', '엑스포시민광장', '신탄진 졸음쉼터', '중문해수욕장주차장', '서귀포시시공원',
#        '제2산록도로 광평교차로', '제주컨벤션센터광장', '천제연폭포주차장', '문화시설', '유원시설', '만안구청',
#        '안양종합운동장', '경인아라뱃길', '안산자락길 숲속카페', '여주종합운동장', '여주프리미엄아울렛',
#        '375st 여주아울렛', '당항포관광지', '자라섬캠핑장', '진부전통시장', '의림지 공영주차장', '숭덕재활원',
#        '평택-제천선 중앙탑 졸음쉼터 내', '이순신공원', '봉산면서부로', '상무시민공원', '풍암호수공원',
#        '황룡친수공원', '서서울톨게이트,(서울방향)졸음쉼터 내', '선문대학교 내',
#        '서서울톨게이트,(목포방향)졸음쉼터 내', '단원구노인복지관', '영남이공대학교 기계공학관 맞은편 공터',
#        '대구 남구 대덕문화전당 주차장 내', '인천가족공원', '아일랜드캐슬 워터파크', '칠곡군', '강촌레일파크푸드',
#        '치요남치킨강촌점', '관악구민종합체육센터', '(코로나19로 잠정 운영 중단)이천농업테마공원 공원부지',
#        '순천향대학교 내', '온양온천시장 이벤트광장(푸드트럭존)', '춘향골체육공원', '독봉산웰빙공원', '지세포친수공간',
#        '거제시보건소', '거제시청', '북서울꿈의숲', '오장폭포주차장', '독산역 2번출구 앞 광장', '신포청년몰',
#        '당진시청', '서해안고속도로 당진 졸음쉼터(상행)', '서해안고속도로 당진 졸음쉼터(하행)', '당진1동행정복지센터',
#        '한밭야구장', '남항대교 하부', '중앙체육공원', '남광주시장', '아시아문화전당', '곡성세계장미축제장',
#        '곡성심청축제장', '인천대학교 BTL생활원 부속시설', '인천송도국제캠핑장', '위덕대학교 학교주차장',
#        '대덕구노인종합복지회관', '신대노인종합복지관', '문화체육회관', '레포츠공원', '테니스파크', '용하체육관',
#        '청춘체육관', '솔오름주차장', '솔오름전망대', '경부선연곡졸음쉼터내영업허용장소', '대명리조트',
#        '덕풍천 자전거 휴게소 내', '풍산근린2호공원', '남해고속도로지수졸음쉼터', '영업자가 신청하여 지정하는 장소',
#        '도시공원', '커피화이트컵', '청남대별장푸드', '흥부카페', '츄로츄러스', '도담다방', '야미(Yummy)',
#        '츄러스브로', '친환경스카이웨이주차장', '갈모봉산림욕장', '화진포관광지', '기타장소', '봉포리 상상마당',
#        '평사리공원', '신례천로옆', '태풍센터근처', '의성마늘테마파크', '의성종합운동장', '의성군농업기술센터',
#        '의성조문국사적지', '빙계군립공원', '이월드', '온천공원', '농업테마파크', '버닝웍', '매튜516',
#        '대로식당', '이카 타코야끼', '드롭탑 오송역 언더패스점', '서동생활공원', '경산생활체육공원',
#        '삼성현역사문화공원', '경일대학교', '대구한의대학교', '청성역사공원 지역', '용평리조트', '알펜시아 리조트',
#        '평창 휘닉스파크', '마하생태관광단지', '평창전통시장', '대화전통시장', '봉평전통시장', '만항재',
#        '남양주체육문화센터 푸드트럭존', '진건도서관', '별내체육공원', '다산동사무소', '금오랜드',
#        '선기졸음쉼터(부산방향)', '선기졸음쉼터(서울방향)', '기장군청', '남광주밤기차야시장', '국립아시아문화전당',
#        '충장축제 행사장', '김대중컨벤션센터', '광주시청(야외스케이트장)', '광주사직공원'], dtype=object)

# %%
food_truck2[food_truck2['구별'].isnull()]
# Out:
# Empty DataFrame
# Columns: [구별, 위도, 경도, 푸드트럭운영대수]
# Index: []

# %%
food_truck2[food_truck2['푸드트럭운영대수'].isnull()]
# Out:
#                       구별         위도          경도  푸드트럭운영대수
# 9                  강변축구장  35.908987  128.590347       NaN
# 10          검단졸음쉼터(부산방향)        NaN         NaN       NaN
# 11          검단졸음쉼터(서울방향)        NaN         NaN       NaN
# 12            구수산도서관 주차장  35.938744  128.552405       NaN
# 53     경상남도수산기술사업소 남해사무소  34.829769  128.008264       NaN
# 105    사적지 제229호 충의사 주차장  36.686537  126.651381       NaN
# 106  유형문화재 제43호 추사고택 주차장  36.746936  126.798459       NaN
# 107            예당관광지 주차장  36.637579  126.799475       NaN
# 108          의좋은형제공원 주차장  36.608266  126.791829       NaN
# 109       덕산도립공원 수덕사 주차장  36.655818  126.620730       NaN
# 110          무한천체육공원 주차장  36.685274  126.822371       NaN
# 111   국립공주대학교 산업과학대학 주차장  36.669888  126.859414       NaN
# 112    봉수산자연휴양림(수목원) 주차장  36.598449  126.780894       NaN
# 113           예산황새공원 주차장  36.542628  126.802244       NaN
# 121          산격대교 인근 축제장        NaN         NaN       NaN
# 122                북구청광장  35.885684  128.582780       NaN
# 129             푸드트럭허가구역  34.316104  126.741107       NaN
# 148             신탄진 졸음쉼터        NaN         NaN       NaN
# 160               경인아라뱃길        NaN         NaN       NaN
# 161               경인아라뱃길        NaN         NaN       NaN
# 162               경인아라뱃길        NaN         NaN       NaN
# 163               경인아라뱃길        NaN         NaN       NaN
# 164               경인아라뱃길        NaN         NaN       NaN
# 171               진부전통시장  37.637800  128.558480       NaN
# 183             단원구노인복지관  37.332269  126.810584       NaN
# 188          아일랜드캐슬 워터파크  37.706949  127.053386       NaN
# 216            곡성세계장미축제장  35.277533  127.308286       NaN
# 217              곡성심청축제장  35.277533  127.308286       NaN
# 220          위덕대학교 학교주차장  36.016110  129.282592       NaN
# 221          대덕구노인종합복지회관  36.378258  127.431439       NaN
# 222            신대노인종합복지관  36.398750  127.420458       NaN
# 260             의성마늘테마파크  36.351376  128.676814       NaN
# 261              의성종합운동장  36.357284  128.693290       NaN
# 262            의성군농업기술센터  36.323022  128.646209       NaN
# 278            청성역사공원 지역        NaN         NaN       NaN
# 279                용평리조트  37.650944  128.705557       NaN
# 280             알펜시아 리조트  37.659254  128.684011       NaN
# 281             평창 휘닉스파크  37.582463  128.326868       NaN
# 282             마하생태관광단지  37.278574  128.576240       NaN
# 283               평창전통시장  37.366849  128.394577       NaN
# 284               대화전통시장  37.500697  128.454714       NaN
# 285               봉평전통시장  37.615481  128.377647       NaN
# 295            남광주밤기차야시장  35.138938  126.921872       NaN
# 296            국립아시아문화전당  35.146916  126.919994       NaN
# 297             충장축제 행사장  35.146916  126.919994       NaN
# 298             김대중컨벤션센터  35.146777  126.840480       NaN
# 299               상무시민공원  35.153393  126.841096       NaN
# 300               풍암호수공원        NaN         NaN       NaN
# 301        광주시청(야외스케이트장)  35.160099  126.851462       NaN
# 302               광주사직공원  35.141622  126.911496       NaN
# 303                 우치공원  35.221534  126.901972       NaN
# 304               황룡친수공원        NaN         NaN       NaN

# %%
food_truck2=food_truck2.dropna()

# %%
food_truck2[food_truck2['푸드트럭운영대수'].isnull()]
# Out:
# Empty DataFrame
# Columns: [구별, 위도, 경도, 푸드트럭운영대수]
# Index: []

# %%
# 정렬된 결과를 파일로 저장 : encoding='euc-kr'
food_truck2.to_csv('../data/food_truck_result.csv',
                      header=True,
                      index=True,
                      encoding='utf-8')

# %%
food_truck2['푸드트럭운영대수'].value_counts() # 운영대수별 지역 수
# Out:
# 1.0     151
# 2.0      18
# 0.0      12
# 4.0       6
# 3.0       5
# 8.0       4
# 5.0       4
# 10.0      2
# 18.0      2
# 9.0       1
# 7.0       1
# 17.0      1
# 12.0      1
# Name: 푸드트럭운영대수, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
food_truck2['푸드트럭운영대수'].value_counts().plot(kind='bar')
# 한대를 운영하는 곳이 압도적으로 많음.
# Out:
# <AxesSubplot:>

# %%
import seaborn
import folium

# %%
food_truck = pd.read_csv('../data/food_truck_result.csv', index_col='구별')
food_truck2.head(10) # 인덱스가 9에서 끊겨서 아래의 지도 표시에서 반복문 실행시 오류
# Out:
#                   구별         위도          경도  푸드트럭운영대수
# 0             완산쳬련공원  35.767445  127.101549       1.0
# 1           부곡온천관광특구  35.441552  128.535214       1.0
# 2          우포 잠자리 나라  35.566697  128.416936       1.0
# 3          고속국도 졸음쉼터  37.679198  126.915782       1.0
# 4            영상강문화공원  35.325205  126.987889       2.0
# 5   인제군농특산물전시판매장 주차장  38.065268  128.174470       2.0
# 6            어울림근린공원  37.896611  127.051710       1.0
# 7      캠프보산 월드푸드스트리트  37.916468  127.056263      12.0
# 8            원주종합체육관  37.339061  127.941916       5.0
# 13          안성시종합운동장  37.014779  127.323606       1.0

# %%
food_truck4=food_truck2.set_index(['구별'])
food_truck4.head()
# Out:
#                   위도          경도  푸드트럭운영대수
# 구별
# 완산쳬련공원     35.767445  127.101549       1.0
# 부곡온천관광특구   35.441552  128.535214       1.0
# 우포 잠자리 나라  35.566697  128.416936       1.0
# 고속국도 졸음쉼터  37.679198  126.915782       1.0
# 영상강문화공원    35.325205  126.987889       2.0

# %%
food_truck4.index
# Out:
# Index(['완산쳬련공원', '부곡온천관광특구', '우포 잠자리 나라', '고속국도 졸음쉼터', '영상강문화공원',
#        '인제군농특산물전시판매장 주차장', '어울림근린공원', '캠프보산 월드푸드스트리트', '원주종합체육관', '안성시종합운동장',
#        ...
#        '삼성현역사문화공원', '경일대학교', '대구한의대학교', '만항재', '남양주체육문화센터 푸드트럭존', '진건도서관',
#        '별내체육공원', '다산동사무소', '금오랜드', '기장군청'],
#       dtype='object', name='구별', length=208)

# %%
# Out:
#                   위도          경도  푸드트럭운영대수
# 구별
# 완산쳬련공원     35.767445  127.101549       1.0
# 부곡온천관광특구   35.441552  128.535214       1.0
# 우포 잠자리 나라  35.566697  128.416936       1.0
# 고속국도 졸음쉼터  37.679198  126.915782       1.0
# 영상강문화공원    35.325205  126.987889       2.0
# ...              ...         ...       ...
# 진건도서관      37.655136  127.177439       1.0
# 별내체육공원     37.659730  127.121360       1.0
# 다산동사무소     37.613927  127.155549       1.0
# 금오랜드       36.113304  128.315585       1.0
# 기장군청       35.243482  129.222956       1.0
#
# [197 rows x 3 columns]

# %%
food_truck_map = folium.Map(location=[37.566345, 126.977893], zoom_start=11)

for name in food_truck4.index:
    folium.Marker([food_truck4['위도'][name], food_truck4['경도'][name]], popup=name).add_to(food_truck_map)


food_truck_map.save('../data/food_truck_map.html')
food_truck_map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\folium\utilities.py in validate_location(location)
#      59         try:
# ---> 60             float(coord)
#      61         except (TypeError, ValueError):
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     128             return converter(self.iloc[0])
# --> 129         raise TypeError(f"cannot convert the series to {converter}")
#     130
#
# TypeError: cannot convert the series to <class 'float'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-8f097fca3308> in <module>
#       2
#       3 for name in food_truck4.index:
# ----> 4     folium.Marker([food_truck4['위도'][name], food_truck4['경도'][name]], popup=name).add_to(food_truck_map)
#       5
#       6
#
# C:\Anaconda3\lib\site-packages\folium\map.py in __init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     275         super(Marker, self).__init__()
#     276         self._name = 'Marker'
# --> 277         self.location = validate_location(location) if location else None
#     278         self.options = parse_options(
#     279             draggable=draggable or None,
#
# C:\Anaconda3\lib\site-packages\folium\utilities.py in validate_location(location)
#      60             float(coord)
#      61         except (TypeError, ValueError):
# ---> 62             raise ValueError('Location should consist of two numerical values, '
#      63                              'but {!r} of type {} is not convertible to float.'
#      64                              .format(coord, type(coord)))
#
# ValueError: Location should consist of two numerical values, but 구별
# 자연학습공원    37.307108
# 자연학습공원    37.307108
# 자연학습공원    37.307108
# Name: 위도, dtype: float64 of type <class 'pandas.core.series.Series'> is not convertible to float.
